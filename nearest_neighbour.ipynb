# %%
import pandas as pd
import re

# %%
# !pip install ftfy
from ftfy import fix_text

def ngrams(string, n=3):
    string = fix_text(string) # fix text
    string = string.encode("ascii", errors="ignore").decode() #remove non ascii chars
    string = string.lower()
    chars_to_remove = [")","(","|","[","]","{","}","'"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']'
    string = re.sub(rx, '', string)
    string = string.replace('&', 'and')
    string = string.replace(',', ' ')
    string = string.replace('-', ' ')
    string = string.replace('.', ' ')
    string = string.title() # normalise case - capital at start of each word
    string = re.sub(' +',' ',string).strip() # get rid of multiple spaces and replace with a single
    string = ' '+ string +' ' # pad names for ngrams...
    string = re.sub(r'[,-./]|\sBD',r'', string)
    string = string.strip()
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]


print(ngrams('Klazenga, N.'))
print(ngrams('Beauglehole, A.C.'))
# Out:
# Requirement already satisfied: ftfy in /opt/conda/lib/python3.7/site-packages (5.7)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from ftfy) (0.1.8)
# ['Kla', 'laz', 'aze', 'zen', 'eng', 'nga', 'ga ', 'a N']
# ['Bea', 'eau', 'aug', 'ugl', 'gle', 'leh', 'eho', 'hol', 'ole', 'le ', 'e A', ' A ', 'A C']

# %%
# Create Wikidata items data frame
df_wikidata = pd.read_csv('data/wikidata_persons.csv')
df_wikidata = df_wikidata.iloc[:, 1:]

df_wikidata.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (9,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                     item                    itemLabel  \
# 0  http://www.wikidata.org/entity/Q67329        Carl Gustav Jablonsky
# 1  http://www.wikidata.org/entity/Q68738               Hermann Müller
# 2  http://www.wikidata.org/entity/Q66902               Hermann Lebert
# 3  http://www.wikidata.org/entity/Q69552  Carl Julius Bernhard Börner
# 4  http://www.wikidata.org/entity/Q66379             Ludwig Bechstein
#
#      surname initials canonical_string orcid       viaf                 isni  \
# 0  Jablonsky     C.G.  Jablonsky, C.G.   NaN   24944037  0000 0000 5526 3001
# 1     Müller       H.       Müller, H.   NaN    2532803  0000 0001 0837 1728
# 2     Lebert       H.       Lebert, H.   NaN   27833384  0000 0001 2100 1924
# 3     Börner   C.J.B.   Börner, C.J.B.   NaN  118457204  0000 0001 1085 9124
# 4  Bechstein       L.    Bechstein, L.   NaN   36914329  0000 0001 2278 3438
#
#     harv     ipni     abbr bloodhound_id enc_au_sc_id     yob     yod  wyb  \
# 0    NaN      NaN      NaN           NaN          NaN  1756.0  1787.0  NaN
# 1  36129   6735-1  H.Müll.           NaN          NaN  1829.0  1883.0  NaN
# 2  67704  22162-1   Lebert           NaN          NaN  1813.0  1878.0  NaN
# 3   1763  12350-1   Börner           NaN          NaN  1880.0  1953.0  NaN
# 4    NaN      NaN      NaN           NaN          NaN  1801.0  1860.0  NaN
#
#    wye
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# Create data frame with unique canonical strings
df_wikidata_unique = df_wikidata.groupby('canonical_string').agg({'item': ['count']}).reset_index()
cols = df_wikidata_unique.columns.tolist()

# df_wikidata_unique
print(df_wikidata_unique.values)
# Out:
# [['(-Walraevens), O.H.' 2]
#  ['(1), G.Z.' 1]
#  ['(Entomologist), C.K.' 1]
#  ...
#  ['Șuster, P.M.' 1]
#  ['Șık, L.' 1]
#  ['Țopa, E.' 1]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorize Wikidata name (use fit_transform())
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix_clean = vectorizer.fit_transform(df_wikidata_unique['canonical_string'])

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=1, n_jobs=-1).fit(tf_idf_matrix_clean) # tfidf contains the vectorized wikidata names from the previous step

# matching query
def getNearestN(query):
  queryTFIDF_ = vectorizer.transform(query)
  distances, indices = nbrs.kneighbors(queryTFIDF_)
  return distances, indices

# %%
def get_matches_df(name_vector, test_df, distances, indices, upper_bound=0.9):
    matches = []
    for i,j in enumerate(indices):
        left_side = name_vector[i]
        right_side = test_df.values[j][0][0]
        distance = round(distances[i][0],2)
        temp = [left_side, right_side, distance]
        matches.append(temp)

    matches = pd.DataFrame(matches, columns=['left_side','right_side','distance'])
    matches = matches[matches['distance'] <= upper_bound]

    matches = matches.sort_values(['distance'])
    matches = matches.reset_index()
    return matches

# %%
# Load AVH collectors data set
df_avh = pd.read_csv('data/avh_collectors.csv')
df_avh = df_avh.iloc[:, 1:]
df_avh.drop(columns=['i18nCode', 'fq'], inplace=True)

df_avh.head()
# Out:
#                label  count  start_date  end_date  activity_span
# 0  Beauglehole, A.C.  90942      1865.0    2005.0          140.0
# 1      Forster, P.I.  64649      1955.0    2018.0           63.0
# 2         Hyland, B.  57265      1952.0    2008.0           56.0
# 3           Latz, P.  51230      1875.0    2019.0          144.0
# 4      Streimann, H.  45346      1896.0    2001.0          105.0

# %%
avh_names = set(df_avh['label'].values)

import time
start = time.time()
print('Getting nearest neighbours...')
distances, indices = getNearestN(avh_names)
duration = time.time() - start
print('Completed in:', duration, 's')

avh_names = list(avh_names)

df_matches = get_matches_df(avh_names, df_wikidata_unique, distances, indices)

print(df_matches.sample(20))
# Out:
# Getting nearest neighbours...
# Completed in: 2.0293214321136475 s
#      index                    left_side         right_side  distance
# 623    855                 Harris, P.L.         Harris, P.      0.54
# 706    640                  Smith, N.M.        Smith, N.P.      0.63
# 790    792                 Stacey, C.I.       Stacey, J.W.      0.76
# 228    696                    Paust, S.          Paust, S.      0.00
# 695    870                  Aston, H.I.          Aston, H.      0.62
# 409    162                   Leiper, G.         Leiper, G.      0.00
# 724    768               Eldridge, D.J.     Eldridge, G.H.      0.65
# 789    621  Gates, G.M.|Ratkowsky, D.A.  Ratkowsky, D.(.).      0.76
# 768    121                   Cronin, M.       Cronin, T.M.      0.72
# 119    470                 Rodway, F.A.       Rodway, F.A.      0.00
# 729    839                    May, T.W.            May, T.      0.66
# 701     47           Leichhardt, F.W.L.     Leichhardt, L.      0.63
# 684    961               Stephens, K.M.       Stephens, J.      0.61
# 753    478                Baker, W.R.A.          Baker, W.      0.69
# 762    380                Wrigley, J.W.      Wrigley, A.G.      0.70
# 870    155                Trenowden, D.      Snowden, J.D.      0.87
# 579    709                   Rankin, M.         Rankin, R.      0.49
# 450    899             Waterhouse, B.M.     Waterhouse, B.      0.39
# 501    424                   Newbey, K.       Newbey, K.R.      0.42
# 820    221                  Allan, K.M.          Allan, J.      0.80

# %%
# Join matches data frame to AVH collectors data frame
df_avh_matches = pd.merge(df_avh, df_matches, left_on='label', right_on='left_side', how='left')

df_avh_matches

# Join Wikidata items
df_avh_matches_wikidata = pd.merge(df_avh_matches, df_wikidata, left_on='right_side', right_on='canonical_string', how='left')
df_avh_matches_wikidata = pd.merge(df_avh_matches_wikidata, df_wikidata_unique, left_on='right_side', right_on='canonical_string', how='left')
df_avh_matches_wikidata.rename(columns={df_avh_matches_wikidata.columns.tolist()[-1]: 'dup_count'}, inplace=True)

# Remove unwanted columns
df_avh_wikidata_nn = df_avh_matches_wikidata[['label', 'count', 'start_date', 'end_date', 'activity_span', 
                                                  'left_side', 'right_side', 'distance', 'dup_count', 
                                                  'item', 'itemLabel', 'surname', 'initials', 'canonical_string', 
                                                  'orcid', 'viaf', 'isni', 'harv', 'ipni', 'abbr', 'bloodhound_id', 
                                                  'enc_au_sc_id', 'yob', 'yod', 'wyb', 'wye']]

# Order by similarity (desc), number of Wikidata items (asc) and number of collections (desc)
df_avh_wikidata_nn.sort_values(by=['distance', 'dup_count', 'count'], ascending=[True, True, False], inplace=True)

df_avh_wikidata_nn
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/merge.py:618: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                         label  count  start_date  end_date  activity_span  \
# 0           Beauglehole, A.C.  90942      1865.0    2005.0          140.0
# 1               Forster, P.I.  64649      1955.0    2018.0           63.0
# 2                  Hyland, B.  57265      1952.0    2008.0           56.0
# 4               Streimann, H.  45346      1896.0    2001.0          105.0
# 5                  Elix, J.A.  39702      1878.0    2020.0          142.0
# ...                       ...    ...         ...       ...            ...
# 1107  Abbott, B. | Burton, E.    705      2008.0    2013.0            5.0
# 1113             Wauchope, J.    695      1923.0    1987.0           64.0
# 1120          Ollerenshaw, N.    692      1874.0    1990.0          116.0
# 1125            Menkins, I.L.    687      1998.0    2012.0           14.0
# 1127            Strudwick, J.    687      1976.0    1998.0           22.0
#
#               left_side         right_side  distance  dup_count  \
# 0     Beauglehole, A.C.  Beauglehole, A.C.       0.0        1.0
# 1         Forster, P.I.      Forster, P.I.       0.0        1.0
# 2            Hyland, B.         Hyland, B.       0.0        1.0
# 4         Streimann, H.      Streimann, H.       0.0        1.0
# 5            Elix, J.A.         Elix, J.A.       0.0        1.0
# ...                 ...                ...       ...        ...
# 1107                NaN                NaN       NaN        NaN
# 1113                NaN                NaN       NaN        NaN
# 1120                NaN                NaN       NaN        NaN
# 1125                NaN                NaN       NaN        NaN
# 1127                NaN                NaN       NaN        NaN
#
#                                           item  ...                 isni  \
# 0     http://www.wikidata.org/entity/Q16744919  ...                  NaN
# 1      http://www.wikidata.org/entity/Q9057027  ...                  NaN
# 2      http://www.wikidata.org/entity/Q4893242  ...                  NaN
# 4     http://www.wikidata.org/entity/Q21339679  ...  0000 0001 1573 7118
# 5     http://www.wikidata.org/entity/Q21339171  ...  0000 0000 8084 828X
# ...                                        ...  ...                  ...
# 1107                                       NaN  ...                  NaN
# 1113                                       NaN  ...                  NaN
# 1120                                       NaN  ...                  NaN
# 1125                                       NaN  ...                  NaN
# 1127                                       NaN  ...                  NaN
#
#        harv     ipni        abbr bloodhound_id enc_au_sc_id     yob     yod  \
# 0       NaN      NaN         NaN     Q16744919     P000214b  1920.0  2002.0
# 1       NaN  18907-1  P.I.Forst.           NaN          NaN  1961.0     NaN
# 2       NaN   4262-1    B.Hyland           NaN          NaN  1937.0     NaN
# 4      2053  15669-1   Streimann           NaN     P005606b  1938.0  2001.0
# 5     93027  18445-1        Elix           NaN     P005725b  1941.0     NaN
# ...     ...      ...         ...           ...          ...     ...     ...
# 1107    NaN      NaN         NaN           NaN          NaN     NaN     NaN
# 1113    NaN      NaN         NaN           NaN          NaN     NaN     NaN
# 1120    NaN      NaN         NaN           NaN          NaN     NaN     NaN
# 1125    NaN      NaN         NaN           NaN          NaN     NaN     NaN
# 1127    NaN      NaN         NaN           NaN          NaN     NaN     NaN
#
#      wyb wye
# 0    NaN NaN
# 1    NaN NaN
# 2    NaN NaN
# 4    NaN NaN
# 5    NaN NaN
# ...   ..  ..
# 1107 NaN NaN
# 1113 NaN NaN
# 1120 NaN NaN
# 1125 NaN NaN
# 1127 NaN NaN
#
# [1140 rows x 26 columns]

# %%
df_avh_wikidata_nn.to_csv('data/avhcoll_wikidata_nn.csv')

# %%
# Load MEL Collectors data set
df_melcoll = pd.read_csv('data/mel_collectors.csv')
df_melcoll['full_name'] = df_melcoll['family_name'] + ', ' + df_melcoll['initials']
df_melcoll = df_melcoll[df_melcoll['num_coll'] >= 1000]

df_melcoll
# Out:
#      agent_id  family_name initials               given_names  num_coll  \
# 0        1297  Beauglehole     A.C.                       NaN     69198
# 1       14283      Mueller      F.   Ferdinand Jacob Heinrich     25429
# 2       19313        Stone     I.G.                       NaN     25428
# 3       21883       Willis     J.H.                     James     20637
# 4        6458       Filson     R.B.                       Rex     15193
# ..        ...          ...      ...                       ...       ...
# 142      8624     Hartmann     C.H.                      Carl      1017
# 143      1609       Betche       E.                     Ernst      1016
# 144      8823       Healey       K.                       NaN      1014
# 145     19882        Thies     A.W.                    Arthur      1002
# 146      7835         Gray       B.                       NaN      1001
#
#      start_year  end_year          full_name
# 0        1929.0    2001.0  Beauglehole, A.C.
# 1        1812.0    1895.0       Mueller, F.
# 2        1960.0    1999.0        Stone, I.G.
# 3        1885.0    1996.0       Willis, J.H.
# 4        1933.0    2000.0       Filson, R.B.
# ..          ...       ...                ...
# 142      1856.0    1889.0     Hartmann, C.H.
# 143      1865.0    1986.0         Betche, E.
# 144      1953.0    1963.0         Healey, K.
# 145      1978.0    1998.0        Thies, A.W.
# 146      1956.0    2011.0           Gray, B.
#
# [147 rows x 8 columns]

# %%
mel_names = set(df_melcoll['full_name'].values)

import time
start = time.time()
print('Getting nearest neighbours...')
distances, indices = getNearestN(avh_names)
duration = time.time() - start
print('Completed in:', duration, 's')

mel_names = list(avh_names)

df_matches = get_matches_df(mel_names, df_wikidata_unique, distances, indices)

print(df_matches.sample(20))
# Out:
# Getting nearest neighbours...
# Completed in: 2.1944732666015625 s
#      index                    left_side         right_side  distance
# 133    425                 Muspratt, J.       Muspratt, J.      0.00
# 778    233              van Leeuwen, S.    Leeuwen, S.J.v.      0.74
# 283    130                     Dahl, E.           Dahl, E.      0.00
# 572    462                   Sharpe, P.       Sharpe, P.R.      0.48
# 529    869                Johnson, D.C.        Johnson, D.      0.45
# 222    707               Camfield, J.H.     Camfield, J.H.      0.00
# 409    162                   Leiper, G.         Leiper, G.      0.00
# 23     495                   Carr, G.W.         Carr, G.W.      0.00
# 610     53                   Wilson, K.         Wilson, [.      0.52
# 250    794                  Ornduff, R.        Ornduff, R.      0.00
# 685    851               Champion, I.G.       Champion, J.      0.61
# 411    289                  Duval, D.J.        Duval, D.J.      0.00
# 758    781                Brooker, M.I.        Brooker, I.      0.70
# 664    956               Woolcock, C.E.       Woolcock, A.      0.58
# 583    840                   Zich, F.A.           Zich, F.      0.49
# 160    834                O'Leary, M.C.      O'Leary, M.C.      0.00
# 606    980                  Parsons, D.        Parsons, J.      0.52
# 558    960                 Schubert, A.       Schubert, J.      0.48
# 301     48                  Brennan, K.        Brennan, K.      0.00
# 789    621  Gates, G.M.|Ratkowsky, D.A.  Ratkowsky, D.(.).      0.76

# %%
# Join matches data frame to MEL collectors data frame
df_melcoll_matches = pd.merge(df_melcoll, df_matches, left_on='full_name', right_on='left_side', how='left')

# Join Wikidata items
df_melcoll_matches_wikidata = pd.merge(df_melcoll_matches, df_wikidata, left_on='right_side', right_on='canonical_string', how='left')
df_melcoll_matches_wikidata = pd.merge(df_melcoll_matches_wikidata, df_wikidata_unique, left_on='right_side', right_on='canonical_string', how='left')
df_melcoll_matches_wikidata.rename(columns={df_melcoll_matches_wikidata.columns.tolist()[-1]: 'dup_count'}, inplace=True)

# Remove unwanted columns
df_melcoll_wikidata_nn = df_melcoll_matches_wikidata[['agent_id', 'family_name', 'initials_x', 'given_names', 
                                                          'num_coll', 'start_year', 'end_year', 'full_name', 
                                                          'left_side', 'right_side', 'distance', 'dup_count', 
                                                          'item', 'itemLabel', 'surname', 'initials_y', 'canonical_string', 
                                                          'orcid', 'viaf', 'isni', 'harv', 'ipni', 'abbr', 'bloodhound_id', 
                                                          'enc_au_sc_id', 'yob', 'yod', 'wyb', 'wye']]

# Sort by similarity (desc), number of Wikidata items (asc) and number of collections (desc)
df_melcoll_wikidata_nn.sort_values(by=['distance', 'dup_count', 'num_coll'], ascending=[True, True, False], inplace=True)

df_melcoll_wikidata_nn
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/merge.py:618: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      agent_id  family_name initials_x    given_names  num_coll  start_year  \
# 0        1297  Beauglehole       A.C.            NaN     69198      1929.0
# 2       19313        Stone       I.G.            NaN     25428      1960.0
# 5        6458       Filson       R.B.            Rex     15193      1933.0
# 6        6771      Forster       P.I.     Paul Irwin     12226      1955.0
# 10      20954        Walsh       N.G.        Neville      9122      1971.0
# ..        ...          ...        ...            ...       ...         ...
# 151      7041     Fullagar       J.P.          James      1121      1860.0
# 163      2729       Bufton         J.            NaN      1061      1853.0
# 164      9524       Hooker       J.D.  Joseph Dalton      1046      1830.0
# 165     21755     Wilhelmi     J.F.C.            NaN      1035      1847.0
# 169      8624     Hartmann       C.H.           Carl      1017      1856.0
#
#      end_year          full_name          left_side         right_side  ...  \
# 0      2001.0  Beauglehole, A.C.  Beauglehole, A.C.  Beauglehole, A.C.  ...
# 2      1999.0        Stone, I.G.        Stone, I.G.        Stone, I.G.  ...
# 5      2000.0       Filson, R.B.       Filson, R.B.       Filson, R.B.  ...
# 6      2118.0      Forster, P.I.      Forster, P.I.      Forster, P.I.  ...
# 10     2020.0        Walsh, N.G.        Walsh, N.G.        Walsh, N.G.  ...
# ..        ...                ...                ...                ...  ...
# 151    1877.0     Fullagar, J.P.                NaN                NaN  ...
# 163    1898.0         Bufton, J.                NaN                NaN  ...
# 164    1902.0       Hooker, J.D.                NaN                NaN  ...
# 165    1887.0   Wilhelmi, J.F.C.                NaN                NaN  ...
# 169    1889.0     Hartmann, C.H.                NaN                NaN  ...
#
#                     isni   harv     ipni        abbr bloodhound_id  \
# 0                    NaN    NaN      NaN         NaN     Q16744919
# 2    0000 0001 1247 4965  40174  27255-1   I.G.Stone           NaN
# 5                    NaN  76762  18803-1      Filson           NaN
# 6                    NaN    NaN  18907-1  P.I.Forst.           NaN
# 10   0000 0000 6385 4733    NaN  14171-1   N.G.Walsh           NaN
# ..                   ...    ...      ...         ...           ...
# 151                  NaN    NaN      NaN         NaN           NaN
# 163                  NaN    NaN      NaN         NaN           NaN
# 164                  NaN    NaN      NaN         NaN           NaN
# 165                  NaN    NaN      NaN         NaN           NaN
# 169                  NaN    NaN      NaN         NaN           NaN
#
#     enc_au_sc_id     yob     yod wyb wye
# 0       P000214b  1920.0  2002.0 NaN NaN
# 2            NaN  1913.0  2001.0 NaN NaN
# 5       P002347b  1930.0     NaN NaN NaN
# 6            NaN  1961.0     NaN NaN NaN
# 10      P005329b  1956.0     NaN NaN NaN
# ..           ...     ...     ...  ..  ..
# 151          NaN     NaN     NaN NaN NaN
# 163          NaN     NaN     NaN NaN NaN
# 164          NaN     NaN     NaN NaN NaN
# 165          NaN     NaN     NaN NaN NaN
# 169          NaN     NaN     NaN NaN NaN
#
# [175 rows x 29 columns]

# %%
# Save to CSV file
df_melcoll_wikidata_nn.to_csv('data/melcoll_wikidata_nn.csv')
